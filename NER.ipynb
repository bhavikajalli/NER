# %%
import pandas as pd

# %%
#names = pd.read_csv('person_names.csv',names = ['String','Cleaned_string','Honorific','First_Name','Middle_Name','Last_name','Suffix','Country','Profession'])
names = pd.read_csv('names_gender.csv',encoding = "ISO-8859-1")
# Out:
# /Users/BhavikaJalli/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
names = names[['string','gender','honorific','first_name','middle_name','last_name','suffix']]
names.head(20)
# Out:
#                  string gender  honorific first_name  middle_name  \
# 0           A. Aiyappan   male        NaN         A.          NaN
# 1      A. Amirthalingam   male        NaN         A.          NaN
# 2            A. Andrews   male        NaN         A.          NaN
# 3      A. Arulpiragasam   male        NaN         A.          NaN
# 4           A. Ayyappan   male        NaN         A.          NaN
# 5           A. B. Brown   male        NaN         A.          NaN
# 6           A. B. Frost   male        NaN     Arthur          NaN
# 7          A. B. Graham   male        NaN         A.          NaN
# 8   A. Bertram Chandler   male        NaN         A.          NaN
# 9          A. Bhimsingh   male        NaN         A.          NaN
# 10           A. Buydens   male        NaN         A.          NaN
# 11       A. C. H. Smith   male        NaN         A.          NaN
# 12           A. Charles   male        NaN         A.          NaN
# ...

# %%
for i in range(len(names)):
# Out:
# 'A. Amirthalingam'
